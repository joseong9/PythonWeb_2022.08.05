# %% [markdown]
# # Folium 지도 시각화

# %%
import folium
folium.__version__
# Out:
# '0.12.1.post1'

# %%
# Open street map에 광주광역시청을 표시
map = folium.Map(location=[35.159841, 126.851784], zoom_start=14)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f992dc01799a44d10b6a2fa73721a636 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f992dc01799a44d10b6a2fa73721a636&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f992dc01799a44d10b6a2fa73721a636 = L.map(
#                 &quot;map_f992dc01799a44d10b6a2fa73721a636&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cda2389b94b20187e1c5ce5146d957fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f992dc01799a44d10b6a2fa73721a636);
#
#
#             var marker_815bc650301f25ed4393f22d657b56a1 = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_f992dc01799a44d10b6a2fa73721a636);
#
#
#         var popup_1a049f4fc6d3dc4f3432710853587105 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_f1336dd7a02a4fa884d19e4ccea83262 = $(`&lt;div id=&quot;html_f1336dd7a02a4fa884d19e4ccea83262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_1a049f4fc6d3dc4f3432710853587105.setContent(html_f1336dd7a02a4fa884d19e4ccea83262);
#
#
#         marker_815bc650301f25ed4393f22d657b56a1.bindPopup(popup_1a049f4fc6d3dc4f3432710853587105)
#         ;
#
#
#
#
#             marker_815bc650301f25ed4393f22d657b56a1.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Open street map에 광주광역시청과 구청을 표시
map = folium.Map(location=[35.159841, 126.851784], zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청'
).add_to(map)
folium.Marker(
    location=[35.146107, 126.923315],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width=200),
    tooltip='광주 동구청'
).add_to(map)
folium.Marker(
    location=[35.152089, 126.889858],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width=200),
    tooltip='광주 서구청'
).add_to(map)
folium.Marker(
    location=[35.1741, 126.912157],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width=200),
    tooltip='광주 북구청'
).add_to(map)
folium.Marker(
    location=[35.132901, 126.902573],
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width=200),
    tooltip='광주 남구청'
).add_to(map)
folium.Marker(
    location=[35.159552, 126.793807],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width=200),
    tooltip='광주 광산구청'
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac1c21e7ce5683649fb920ab4c993490 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac1c21e7ce5683649fb920ab4c993490&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ac1c21e7ce5683649fb920ab4c993490 = L.map(
#                 &quot;map_ac1c21e7ce5683649fb920ab4c993490&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cabed48ab523793b67b5ed7171b2076 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ac1c21e7ce5683649fb920ab4c993490);
#
#
#             var marker_66853f4de4f44756e7e6112fdb267d2c = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_ac1c21e7ce5683649fb920ab4c993490);
#
#
#         var popup_c6f8efce8680e7925ad64ef2ce27e6a0 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_b1db62a03f6df83211f6454e9dca76fa = $(`&lt;div id=&quot;html_b1db62a03f6df83211f6454e9dca76fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_c6f8efce8680e7925ad64ef2ce27e6a0.setContent(html_b1db62a03f6df83211f6454e9dca76fa);
#
#
#         marker_66853f4de4f44756e7e6112fdb267d2c.bindPopup(popup_c6f8efce8680e7925ad64ef2ce27e6a0)
#         ;
#
#
#
#
#             marker_66853f4de4f44756e7e6112fdb267d2c.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d2b68f55a9bec007cf27ce9c4c9f97b0 = L.marker(
#                 [35.146107, 126.923315],
#                 {}
#             ).addTo(map_ac1c21e7ce5683649fb920ab4c993490);
#
#
#         var popup_0753e5cc6250be1853965eaa982681df = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_6254c2362b2b9fb037685162fd7755db = $(`&lt;div id=&quot;html_6254c2362b2b9fb037685162fd7755db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_0753e5cc6250be1853965eaa982681df.setContent(html_6254c2362b2b9fb037685162fd7755db);
#
#
#         marker_d2b68f55a9bec007cf27ce9c4c9f97b0.bindPopup(popup_0753e5cc6250be1853965eaa982681df)
#         ;
#
#
#
#
#             marker_d2b68f55a9bec007cf27ce9c4c9f97b0.bindTooltip(
#                 `&lt;div&gt;
#                      광주 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_638dd224bd4012e623054ad6bd9ce248 = L.marker(
#                 [35.152089, 126.889858],
#                 {}
#             ).addTo(map_ac1c21e7ce5683649fb920ab4c993490);
#
#
#         var popup_bb7a023e745dfc7f58b7b22f7a8bd100 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_1f7a2b573acecb799b9d80d72e6c744d = $(`&lt;div id=&quot;html_1f7a2b573acecb799b9d80d72e6c744d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_bb7a023e745dfc7f58b7b22f7a8bd100.setContent(html_1f7a2b573acecb799b9d80d72e6c744d);
#
#
#         marker_638dd224bd4012e623054ad6bd9ce248.bindPopup(popup_bb7a023e745dfc7f58b7b22f7a8bd100)
#         ;
#
#
#
#
#             marker_638dd224bd4012e623054ad6bd9ce248.bindTooltip(
#                 `&lt;div&gt;
#                      광주 서구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e8963bb3bffa0c54c5844e53307b8a99 = L.marker(
#                 [35.1741, 126.912157],
#                 {}
#             ).addTo(map_ac1c21e7ce5683649fb920ab4c993490);
#
#
#         var popup_77cf0c6c478b627c8ef899d2217ac55d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_92af0844e1a63aed41f52979867874ff = $(`&lt;div id=&quot;html_92af0844e1a63aed41f52979867874ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 북구 우치로 77&lt;/div&gt;`)[0];
#             popup_77cf0c6c478b627c8ef899d2217ac55d.setContent(html_92af0844e1a63aed41f52979867874ff);
#
#
#         marker_e8963bb3bffa0c54c5844e53307b8a99.bindPopup(popup_77cf0c6c478b627c8ef899d2217ac55d)
#         ;
#
#
#
#
#             marker_e8963bb3bffa0c54c5844e53307b8a99.bindTooltip(
#                 `&lt;div&gt;
#                      광주 북구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4db07812ede69f60d00e1bde4c968ba4 = L.marker(
#                 [35.132901, 126.902573],
#                 {}
#             ).addTo(map_ac1c21e7ce5683649fb920ab4c993490);
#
#
#         var popup_ac764bf341c0858bc0dfaa54288f29de = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_

# %%
map.save('광주시_주요관공서.html')

# %%
# Stamen Toner map에 광주광역시청과 구청을 표시
from folium.features import CustomIcon, DivIcon

map = folium.Map(location=[35.159841, 126.851784], tiles="Stamen Toner", zoom_start=13)
folium.Marker(
    location=[35.159841, 126.851784],
    popup=folium.Popup('광주광역시 서구 내방로 111', max_width=200),
    tooltip='광주광역시청',
    icon=CustomIcon('광주시청.jpg', icon_size=(60,100))
).add_to(map)
folium.Marker(
    location=[35.146107, 126.923315],
    popup=folium.Popup('광주광역시 동구 서남로 1', max_width=200),
    tooltip='광주 동구청',
    icon=DivIcon(icon_size=(100,20), icon_anchor=(0,0),
                 html='<div style="font-size: 14pt; background-color: powderblue"><bold>광주 동구청</bold></div>')
).add_to(map)
folium.Circle(
    radius=250,
    location=[35.152089, 126.889858],
    popup=folium.Popup('광주광역시 서구 농성동 경열로 33', max_width=200),
    tooltip='광주 서구청',
    color='magenta',
    fill=True
).add_to(map)
folium.CircleMarker(
    radius=20,
    location=[35.1741, 126.912157],
    popup=folium.Popup('광주광역시 북구 우치로 77', max_width=200),
    tooltip='광주 북구청',
    color="#3186aa",        # RGB, 16진수
    fill=True,
    fill_color="#3186dd"
).add_to(map)
folium.Marker(
    location=[35.132901, 126.902573],
    popup=folium.Popup('광주광역시 남구 봉선로 1', max_width=200),
    tooltip='광주 남구청',
    icon=folium.Icon('darkred', icon='star')
).add_to(map)
folium.Marker(
    location=[35.159552, 126.793807],
    popup=folium.Popup('광주광역시 광산구 광산로29번길 15', max_width=200),
    tooltip='광주 광산구청',
    icon=folium.Icon('blue', icon='plane')
).add_to(map)

title_html = '<h3 align="center">광주광역시 주요 행정기관</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44d60f31d2e6a6c71bacc3fb920de60d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#     &lt;h3 align=&quot;center&quot;&gt;광주광역시 주요 행정기관&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44d60f31d2e6a6c71bacc3fb920de60d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_44d60f31d2e6a6c71bacc3fb920de60d = L.map(
#                 &quot;map_44d60f31d2e6a6c71bacc3fb920de60d&quot;,
#                 {
#                     center: [35.159841, 126.851784],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac925f6652de9e844f5ff730554d25a6 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44d60f31d2e6a6c71bacc3fb920de60d);
#
#
#             var marker_265b63605ff41ec398bb7a0e305810eb = L.marker(
#                 [35.159841, 126.851784],
#                 {}
#             ).addTo(map_44d60f31d2e6a6c71bacc3fb920de60d);
#
#
#         var custom_icon_67ee6aaafdb3d4ee6c6bb50510c9cd55 = L.icon({&quot;iconSize&quot;: [60, 100], &quot;iconUrl&quot;: &quot;data:image/jpg;base64,...&quot;});
#         marker_265b63605ff41ec398bb7a0e305810eb.setIcon(custom_icon_67ee6aaafdb3d4ee6c6bb50510c9cd55);
#
#
#         var popup_fa948c38dc03f0ce6dc410680e0c8ade = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_9e58b10c7d4005e67f59663998e631de = $(`&lt;div id=&quot;html_9e58b10c7d4005e67f59663998e631de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 내방로 111&lt;/div&gt;`)[0];
#             popup_fa948c38dc03f0ce6dc410680e0c8ade.setContent(html_9e58b10c7d4005e67f59663998e631de);
#
#
#         marker_265b63605ff41ec398bb7a0e305810eb.bindPopup(popup_fa948c38dc03f0ce6dc410680e0c8ade)
#         ;
#
#
#
#
#             marker_265b63605ff41ec398bb7a0e305810eb.bindTooltip(
#                 `&lt;div&gt;
#                      광주광역시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a457c604d8aee1167d4f32b37c0ac459 = L.marker(
#                 [35.146107, 126.923315],
#                 {}
#             ).addTo(map_44d60f31d2e6a6c71bacc3fb920de60d);
#
#
#             var div_icon_460cb2a6428a074ce9ae71c895539e7b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 14pt; background-color: powderblue\&quot;\u003e\u003cbold\u003e\uad11\uc8fc \ub3d9\uad6c\uccad\u003c/bold\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [100, 20]});
#             marker_a457c604d8aee1167d4f32b37c0ac459.setIcon(div_icon_460cb2a6428a074ce9ae71c895539e7b);
#
#
#         var popup_3d5ff4b54c5d0b0828f334ffccf2cc4d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_5509f06e64932e723c428789cb891216 = $(`&lt;div id=&quot;html_5509f06e64932e723c428789cb891216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 동구 서남로 1&lt;/div&gt;`)[0];
#             popup_3d5ff4b54c5d0b0828f334ffccf2cc4d.setContent(html_5509f06e64932e723c428789cb891216);
#
#
#         marker_a457c604d8aee1167d4f32b37c0ac459.bindPopup(popup_3d5ff4b54c5d0b0828f334ffccf2cc4d)
#         ;
#
#
#
#
#             marker_a457c604d8aee1167d4f32b37c0ac459.bindTooltip(
#                 `&lt;div&gt;
#                      광주 동구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_432f6cf83ceca0c7d5f5b3afc91fbb4e = L.circle(
#                 [35.152089, 126.889858],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;magenta&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;magenta&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44d60f31d2e6a6c71bacc3fb920de60d);
#
#
#         var popup_6d179b56332a33d722c4ebf0a2a70655 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#             var html_e03c9909dc6793eedfe7693f03b5c37f = $(`&lt;div id=&quot;html_e03c9909dc6793eedfe7693f03b5c37f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주광역시 서구 농성동 경열로 33&lt;/div&gt;`)[0];
#             popup_6d179b56332a33d722c4ebf0a2a70655.setContent(html_e03c9909dc6793eedfe7693f03b5c37f);
#
#
#         circle_432f6cf83ceca0c7d5f5b3afc91fbb4e.bindPopup(popup_6d179b56332a33d722c4ebf0a2a70655)
#         ;
#
#
#
#
#             circle
